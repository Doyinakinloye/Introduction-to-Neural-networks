# %% [markdown]
# # Introduction to Regression with Neural Networks in Tensorflow
#
# We're going to be predicting a number based on some other numbers(features)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create features
x = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 42.0, 15.0, 18.0, 21.0, 24.0])
plt.scatter(x, y);
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7d8e509d36a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#     280
#     281
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     129         for manager in cls.get_all_fig_managers():
#     130             if force or manager.canvas.figure.stale:
# --> 131                 manager.canvas.draw_idle()
#     132
#     133
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1889         if not self._is_idle_drawing:
#    1890             with self._idle_draw_cntx():
# ...

# %% [markdown]
# ### Input and output shapes

# %%
# Create a demo tensor for our housing prediction prices
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])

# %%
x = x.reshape(-1, 1)

# %%
input_shape = x.shape
output_shape = y.shape
input_shape, output_shape
# Out:
# ((8, 1), (8,))

# %%
# Turn our numpy arrays to tensors
x = tf.cast(tf.constant(x), dtype=tf.float32)
y = tf.cast(tf.constant(y), dtype=tf.float32)
x, y
# Out:
# (<tf.Tensor: shape=(8, 1), dtype=float32, numpy=
#  array([[-7.],
#         [-4.],
#         [-1.],
#         [ 2.],
#         [ 5.],
#         [ 8.],
#         [11.],
#         [14.]], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 42., 15., 18., 21., 24.], dtype=float32)>)

# %% [markdown]
# ## Steps in modelling in Tensorflow
#
# 1. **Creating a model** - define the input and output layers, as well as the hidden layers of a deep learning model.
# 2. **Compiling a model** - define the loss function(in other words, the function that tells our model how wrong it is) and the optimizer(tells our model how to improve the patterns it is learning) and evaluation metrics(what we can use to interpret the performance of our model).
# 3. **Fitting the model** - Allowing the model find patterns between X & Y (Features and Labels).

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model using the sequential API
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit the model
model.fit(x, y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - loss: 21.0348 - mae: 21.0348
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 20.7535 - mae: 20.7535
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 20.4723 - mae: 20.4723
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 20.1910 - mae: 20.1910
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 19.9098 - mae: 19.9098

# %%
# Make a prediction
model.predict(np.array([17.0]).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# array([[-10.184016]], dtype=float32)

# %% [markdown]
# ### Improving our model
#
# We can improve our model by altering the steps used in creating the model

# %%
# Lets rebuild the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["mae"])
model_1.fit(x, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 16.6148 - mae: 16.6148
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 16.4823 - mae: 16.4823
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 16.3498 - mae: 16.3498
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 16.2173 - mae: 16.2173
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 16.0848 - mae: 16.0848
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 15.9523 - mae: 15.9523
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 15.8198 - mae: 15.8198
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 15.6873 - mae: 15.6873
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 15.5548 - mae: 15.5548
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 15.4223 - mae: 15.4223
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 15.2898 - mae: 15.2898
# Epoch 12/100
# ...

# %%
model_1.predict(np.array([17.0]).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# array([[29.527613]], dtype=float32)

# %%
# Lets tweak somethings
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(1)
])
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=["mae"])
model_2.fit(x, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 16.6771 - mae: 16.6771
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 15.8892 - mae: 15.8892
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 15.0967 - mae: 15.0967
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 14.5209 - mae: 14.5209
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 13.9564 - mae: 13.9564
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 13.3661 - mae: 13.3661
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 12.7546 - mae: 12.7546
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 12.1267 - mae: 12.1267
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.4712 - mae: 11.4712
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 10.7901 - mae: 10.7901
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 10.0865 - mae: 10.0865
# Epoch 12/100
# ...

# %%
model_2.predict(np.array([17.0]).reshape(-1, 1))

# %%
# Lets try and improve on the model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation=None),
    tf.keras.layers.Dense(1)
])
model_3.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=["mae"])
model_3.fit(x, y, epochs=100)

# %%
model_3.predict(np.array([17.0]).reshape(-1, 1))

# %% [markdown]
# ## Evaluating the model

# %%
# Make a bigger dataset
X = tf.range(-100, 100, 4)
X

# %%
Y = X +10
Y

# %%
# Visualize the data
plt.plot(X, Y);

# %%
X_train = X[:35]
Y_train = Y[:35]
X_test = X[35:]
Y_test = Y[35:]
X_train, Y_train, X_test, Y_test

# %%
# Lets look at how to build a neural network for our new data

# 1. Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1], name="input_layer"),
    tf.keras.layers.Dense(1, name="Output_layer")
], name="First_model")
# 2. Compile the model
model.compile(loss="mae",
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics=["mae"])

# %%
model.summary()

# %%
# Let's fit the model on the training data
# 3. Fit the model
model.fit(X_train, Y_train, epochs=100)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Visualizing our model's prediction
#
# To visualize predictions, it's a good idea to plot them against a ground truth labels.
# Often you'll see this in the form of `y_test` or `y_true` versus `y_pred` (ground truth versus your model's predictions)

# %%
# Make some predictions
y_pred = model.predict(X_test)
y_pred

# %%
Y_test

# %%
# Let's create a plotting function
def plot_predictions(train_data=X_train,
                     train_labels=Y_train,
                     test_data=X_test,
                     test_labels=Y_test,
                     predictions=y_pred):
  """Plots training data and compares predictions against ground truth labels."""
  plt.figure(figsize=(10, 7))
  # Plot training data in  blue
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  # Plot testing data in green
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  # Plot the predictions in red
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  # Show the legend
  plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_215/1141997875.py in <cell line: 0>()
#       4                      test_data=X_test,
#       5                      test_labels=Y_test,
# ----> 6                      predictions=y_pred):
#       7   """Plots training data and compares predictions against ground truth labels."""
#       8   plt.figure(figsize=(10, 7))
#
# NameError: name 'y_pred' is not defined

# %%
plot_predictions()

# %% [markdown]
# ### Evaluating our Model's predictions with regression evaluation metrics
#
# Depending on the problem you're working on, there will be different evaluation metrics to evaluate your model's performance.
#
# Since we're working on a regression, two of the main metrics:
# * MAE - mean absolute error, "on average, how wrong is each of my model's predictions."
# * MSE - mean square error, "square of the average of our error"

# %%
#  Evaluate the model on the test set
model.evaluate(X_test, Y_test)

# %%
y_pred = tf.squeeze(y_pred)

# %%
# Calculate the mean absolute error
mae = tf.metrics.mae(Y_test, y_pred)
mae

# %%
# Calculate the mean square error
mse = tf.metrics.mse(Y_test, y_pred)
mse

# %%
# calculate the huber
tf.metrics.huber(Y_test, y_pred)

# %% [markdown]
# ### Running experiments to improve the model

# %%
X_train, Y_train

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1]),
    tf.keras.layers.Dense(1)
])
model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=["mae"])
model_1.fit(X_train, Y_train, epochs=100)

# %%
y_preds_1 = model_1.predict(X_test)
plot_predictions(predictions=y_preds_1)

# %%
y_preds_1 = tf.squeeze(y_preds_1)

# %%
mae_1 = tf.metrics.mae(Y_test, y_preds_1)
mae_1

# %%
mse_1 = tf.metrics.mse(Y_test, y_preds_1)
mse_1

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(20, input_shape=[1]),
    tf.keras.layers.Dense(1)
])
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=["mae"])
model_2.fit(X_train, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 12.0845 - mae: 12.0845
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 6.8883 - mae: 6.8883
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.4156 - mae: 8.4156
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.5521 - mae: 6.5521
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.4881 - mae: 7.4881
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.3368 - mae: 7.3368
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.3894 - mae: 6.3894
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.3155 - mae: 6.3155
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.2588 - mae: 6.2588
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.4080 - mae: 6.4080
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.1507 - mae: 6.1507
# Epoch 12/200
# ...

# %%
y_preds_2 = model_2.predict(X_test)
plot_predictions(predictions=y_preds_2)

# %%
y_preds_2 = tf.squeeze(y_preds_2)

# %%
mse_2 = tf.metrics.mse(Y_test, y_preds_2)
mse_2

# %%
mae_2 = tf.metrics.mae(Y_test, y_preds_2)
mae_2

# %% [markdown]
# ### Comparing the results of our experiments
#
# We've run a few experiments, let's compare the results.

# %%
# let's compare our model's results using pandas Datrframe
import pandas as pd
Model_results = [["model_1", mae.numpy(), mse.numpy()],
                 ["model_2", mae_1.numpy(), mse_1.numpy()],
                 ["model_3", mae_2.numpy(), mse_2.numpy()]]

all_results = pd.DataFrame(Model_results, columns=["model", "mae", "mse"])
all_results

# %% [markdown]
# ## Saving and loading our model
# Saving our model allows us to use them outside of google colab(in a web appliation or mobile app)
#
# 1). The SavedModel format
#
# 2). The HDF5 Format

# %%
# Save model using the HDF5 Format
model_2.save("Best_model.h5")

# %%
# Save model using SavedModel format
model_2.save("my_best_model.keras")

# %%
# Load the model(using the SavedModel Format)
loaded_model = tf.keras.models.load_model("my_best_model.keras")
loaded_model.summary()

# %%
# Load the model(using the HDF5 format)
loaded_model = tf.keras.models.load_model("Best_model.h5")
loaded_model.summary()

# %% [markdown]
# ## A Larger Example

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read in the insurance dataset
insurance = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/refs/heads/master/insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Check for missing values in dataset
insurance.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Lets one-hot encode our dataframe
insurance_encoded = pd.get_dummies(insurance)

# %%
insurance_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1338 non-null   int64
#  1   bmi               1338 non-null   float64
#  2   children          1338 non-null   int64
#  3   charges           1338 non-null   float64
#  4   sex_female        1338 non-null   bool
#  5   sex_male          1338 non-null   bool
#  6   smoker_no         1338 non-null   bool
#  7   smoker_yes        1338 non-null   bool
#  8   region_northeast  1338 non-null   bool
#  9   region_northwest  1338 non-null   bool
#  10  region_southeast  1338 non-null   bool
#  11  region_southwest  1338 non-null   bool
# dtypes: bool(8), float64(2), int64(2)
# memory usage: 52.4 KB

# %%
insurance_encoded.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Create X and Y values
X = insurance_encoded.drop("charges", axis=1)
Y = insurance_encoded["charges"]

# %%
X
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0      19  27.900         0        True     False      False        True
# 1      18  33.770         1       False      True       True       False
# 2      28  33.000         3       False      True       True       False
# 3      33  22.705         0       False      True       True       False
# 4      32  28.880         0       False      True       True       False
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3       False      True       True       False
# 1334   18  31.920         0        True     False       True       False
# 1335   18  36.850         0        True     False       True       False
# 1336   21  25.800         0        True     False       True       False
# 1337   61  29.070         0        True     False      False        True
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
len(X), len(X_train), len(X_test)
# Out:
# (1338, 1070, 268)

# %%
# Build a neural network

insurance_model = tf.keras.Sequential([
    tf.keras.layers.Dense(20),
    tf.keras.layers.Dense(1)
])

insurance_model.compile(loss=tf.keras.losses.mae,
                        optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                        metrics=["mae"])

insurance_model.fit(X_train, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13823.2275 - mae: 13823.2275
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12622.4961 - mae: 12622.4961
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11483.1055 - mae: 11483.1055
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10210.6992 - mae: 10210.6992
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8283.3428 - mae: 8283.3428
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7472.0679 - mae: 7472.0679
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7570.6484 - mae: 7570.6484
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7826.2466 - mae: 7826.2466
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7445.2500 - mae: 7445.2500
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7002.2539 - mae: 7002.2539
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7796.3447 - mae: 7796.3447
# ...

# %%
insurance_model.evaluate(X_test, Y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3535.6931 - mae: 3535.6931
# [3456.721435546875, 3456.721435546875]

# %% [markdown]
# Let's improve on the model

# %%
# Fit for longer
insurance_model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(20),
    tf.keras.layers.Dense(1)
])
insurance_model_2.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                          metrics=["mae"])
history = insurance_model_2.fit(X_train, Y_train, epochs=300)
# Out:
# Epoch 1/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12953.6885 - mae: 12953.6885
# Epoch 2/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13470.7686 - mae: 13470.7686
# Epoch 3/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12434.0078 - mae: 12434.0078
# Epoch 4/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9837.8008 - mae: 9837.8008
# Epoch 5/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8458.4531 - mae: 8458.4531
# Epoch 6/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7515.2290 - mae: 7515.2290
# Epoch 7/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7660.9668 - mae: 7660.9668
# Epoch 8/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7142.0674 - mae: 7142.0674
# Epoch 9/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7080.7622 - mae: 7080.7622
# Epoch 10/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7450.2588 - mae: 7450.2588
# Epoch 11/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6684.5298 - mae: 6684.5298
# ...

# %%
insurance_model_2.evaluate(X_test, Y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3294.9541 - mae: 3294.9541
# [3228.5986328125, 3228.5986328125]

# %%
# Change the activation function and add an extra layer
# add earlystopping
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor="loss", patience=10)

insurance_model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(20),
    tf.keras.layers.Dense(1)
])
insurance_model_3.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                          metrics=["mae"])
insurance_model_3.fit(X_train, Y_train, epochs=200, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12858.0029 - mae: 12858.0029
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7231.8022 - mae: 7231.8022
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7359.4946 - mae: 7359.4946
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6883.9302 - mae: 6883.9302
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6654.0806 - mae: 6654.0806
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6315.1304 - mae: 6315.1304
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5760.0874 - mae: 5760.0874
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6431.8906 - mae: 6431.8906
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6166.1855 - mae: 6166.1855
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5628.0610 - mae: 5628.0610
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5693.2808 - mae: 5693.2808
# ...

# %%
insurance_model_3.evaluate(X_test, Y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2227.2781 - mae: 2227.2781
# [2125.572021484375, 2125.572021484375]

# %%
# Plot history( training curve )
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Preprocessing Data(Normalization and standardization)
#
# In terms of scaling values, neural networks to prefer normalisation.

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# To prepare our data, we can borrow a few classes from sklearn

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# Make a column transformer
ct = make_column_transformer(
    (MinMaxScaler(), ["age", "bmi", "children"]),
    (OneHotEncoder(handle_unknown="ignore"), ["sex", "smoker", "region"])
)

# %%
ct
# Out:
# ColumnTransformer(transformers=[('minmaxscaler', MinMaxScaler(),
#                                  ['age', 'bmi', 'children']),
#                                 ('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['sex', 'smoker', 'region'])])

# %%
# Create X and Y
X = insurance.drop("charges", axis=1)
Y = insurance["charges"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Fit the column transformer to our training data
ct.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('minmaxscaler', MinMaxScaler(),
#                                  ['age', 'bmi', 'children']),
#                                 ('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['sex', 'smoker', 'region'])])

# %%
# Transform training and test data with normalization and OneHotEncoding
X_train_normal = ct.transform(X_train)
X_test_normal = ct.transform(X_test)

# %%
# What does our data look like now?
X_train_normal[0]
# Out:
# array([0.60869565, 0.10734463, 0.4       , 1.        , 0.        ,
#        1.        , 0.        , 0.        , 1.        , 0.        ,
#        0.        ])

# %%
# compare the shapes of our data
X_train.shape, X_train_normal.shape
# Out:
# ((1070, 6), (1070, 11))

# %% [markdown]
# Our data has been normalized.... Now, let's build a neural network on it and see how it goes

# %%
tf.random.set_seed(42)

insurance_model_normal = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(100, activation="relu"),
        tf.keras.layers.Dense(10),
        tf.keras.layers.Dense(1)]
)
insurance_model_normal.compile(loss=tf.keras.losses.mae,
                              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                               metrics=["mae"]
                               )
insurance_model_normal.fit(X_train_normal, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13269.1816 - mae: 13269.1816
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12394.6143 - mae: 12394.6143
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8904.4609 - mae: 8904.4609
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7683.4009 - mae: 7683.4009
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7250.4556 - mae: 7250.4556
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6725.8477 - mae: 6725.8477
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5983.5645 - mae: 5983.5645
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4953.5117 - mae: 4953.5117
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4007.0581 - mae: 4007.0581
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3614.0608 - mae: 3614.0608
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3529.0737 - mae: 3529.0737
# ...

# %%
insurance_model_normal.evaluate(X_test_normal, Y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1744.7546 - mae: 1744.7546
# [1746.851806640625, 1746.851806640625]
